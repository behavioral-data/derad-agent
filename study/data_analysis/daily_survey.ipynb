# %% [markdown]
# **IMPORTANT: CLEAR OUTPUTS BEFORE PUSHING**

# %%
import pandas as pd

PRE_SURVEY_FILEPATH = "input/pre_survey.csv"
DAILY_SURVEY_FILEPATH = "input/daily_survey.csv"

pre_survey_df = pd.read_csv(PRE_SURVEY_FILEPATH)
pre_survey_df = pre_survey_df.rename(columns={
    'tone condition': 'tone_condition',
    'topic condition': 'topic_condition',
    'pre-survey completion time': 'presurvey_timestamp',
    'registration date': 'registration_date'
})

daily_survey_df = pd.read_csv(DAILY_SURVEY_FILEPATH)
daily_survey_df.columns = daily_survey_df.columns.str.split('.').str[0]
daily_survey_df = daily_survey_df.rename(columns={
    'Email Address': 'email',
    """Did the bot respond to your mention with a fact-check? If the bot responded that the claim was not able to be fact-checked, or if you accidentally missed one of your 10 posts from the previous day, select "No""": 'valid_reply',
    """Four-Letter Code""": 'reply_id',
    """To confirm that you viewed the bot's reply, write the username of the user who posted the original post that you replied to when mentioning the bot""": 'parent_author',
    """Rate your agreement with the following statement: I enjoyed this interaction with the bot""": 'enjoyment',
    """Rate your agreement with the following statement: The bot's post was informative""": 'informativeness',
    """Rate your agreement with the following statement: I was satisfied with the quality of the bot's fact-check""": 'satisfaction',
    """(Optional) If any specific details about the bot's reply informed your answers to the questions above, please provide a 2-3 sentence reasoning here""": 'long_answer_main',
    """(If applicable) Rate your agreement with the following statement: Reading the replies to the bot's post makes me interested in following the discussion thread on this post""": 'reply_interest_following',
    """(If applicable)  Rate your agreement with the following statement: Reading the replies to the bot's post makes me interested in engaging in the discussion thread on this post""": 'reply_interest_engaging',
    """(If applicable) Please provide a 2-3 sentence reasoning for your answers to the questions above""": 'long_answer_extra'
})

# %%
pre_survey_df.head(10)
# Out:
#                         email         username tone_condition topic_condition  \
# 0              cluong9@uw.edu     Cheezwhizcat      satirical     LGBT Issues
# 1      jerrybro2001@gmail.com       NekoHuffer        neutral     Immigration
# 2  dlee1004@cs.washington.edu   GarlicBread889      agreeable      Healthcare
# 3             alim1127@uw.edu        lommyt7s8        neutral  Cost of Living
# 4             andreye@mit.edu    JohnAdamsaydj      satirical        Religion
# 5                hsu01@uw.edu  VanillaMatchaHK      agreeable            Race
# 6              weng611@uw.edu        1hyunweng        neutral     LGBT Issues
# 7             azhang64@uw.edu         @jiji88r      satirical     Immigration
# 8             hzhang31@uw.edu    @kevin_yuyuyu      agreeable  Cost of Living
# 9  samira.s.shirazy@gmail.com         Wami3lx9        neutral        Religion
#
#   presurvey_timestamp registration_date  notes
# 0     5/22/2026 21:59         5/24/2026    NaN
# 1     5/24/2026 12:06         5/24/2026    NaN
# 2     5/25/2026 16:31         5/26/2026    NaN
# 3     5/25/2026 17:39         5/26/2026    NaN
# 4     5/26/2026 13:31          6/6/2026    NaN
# 5     5/26/2026 15:44         5/27/2026    NaN
# 6     5/26/2026 20:09         5/29/2026    NaN
# 7     5/27/2026 11:32         5/29/2026    NaN
# 8     5/27/2026 15:44         5/29/2026    NaN
# 9     5/28/2026 15:37         5/29/2026    NaN

# %%
daily_survey_df.head(10)
# Out:
#             Timestamp                       email valid_reply reply_id  \
# 0   5/27/2026 2:13:55      jerrybro2001@gmail.com         Yes     MNFX
# 1   5/27/2026 2:26:47              cluong9@uw.edu         Yes     PLHS
# 2  5/27/2026 11:33:32  dlee1004@cs.washington.edu         Yes     BJRH
# 3   5/28/2026 1:00:29              cluong9@uw.edu         Yes     LGYK
# 4   5/28/2026 1:13:24      jerrybro2001@gmail.com         Yes     CGVS
# 5  5/28/2026 14:23:27             alim1127@uw.edu         Yes     RNHQ
# 6  5/28/2026 23:47:13              cluong9@uw.edu         Yes     GBAE
# 7   5/29/2026 0:43:45      jerrybro2001@gmail.com          No     CACD
# 8  5/29/2026 14:05:52             alim1127@uw.edu         Yes     ZYFG
# 9  5/29/2026 15:19:25                hsu01@uw.edu         Yes     VQCQ
#
#       parent_author  enjoyment  informativeness  satisfaction  \
# 0    ForgiatoBlow47        6.0              5.0           5.0
# 1    @MaeveHalligan        8.0             10.0           6.0
# 2   @KristanHawkins        7.0              8.0           6.0
# 3  @realBrandonGill       10.0              9.0           9.0
# 4     TruthFairy131        8.0              8.0           8.0
# 5  @TripleNetInvest        6.0              8.0           7.0
# 6    @laurenboebert        8.0              9.0           9.0
# 7        Notwokenow        NaN              NaN           NaN
# 8        @benonwine        7.0              8.0           7.0
# 9       @kangminlee        8.0              7.0           5.0
#
#                                     long_answer_main  \
# 0  The bot didn’t really provide many details tha...
# 1  Though brief in its reply, the bot did fact ch...
# 2                                                NaN
# 3  Phenomenal work on the bot, I really liked how...
# 4  The bot gave a lot of details that were suppor...
# 5                                                NaN
# 6  Nothing about the bots reply, but I'm really l...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    reply_interest_following  ...  valid_reply reply_id   parent_author  \
# 0                       6.0  ...          Yes     ETKQ   SenTuberville
# 1                       NaN  ...           No      NaN             NaN
# 2                       NaN  ...           No      NaN             NaN
# 3                       NaN  ...          Yes     PHKL     @joeroganhq
# 4                       5.0  ...          Yes     QGBU         Milajoy
# 5                       3.0  ...           No     NYLK      @lapdoteth
# 6                       NaN  ...          Yes     PHGK     @_Achetypal
# 7                       NaN  ...          Yes     AGNQ      WhiteHouse
# 8                       5.0  ...          Yes     QXAT  @ChuckGrassley
# 9                       5.0  ...           No      NaN             NaN
#
#   enjoyment informativeness  satisfaction  \
# 0       7.0             7.0           6.0
# 1       NaN             NaN           NaN
# 2       NaN             NaN           NaN
# 3      10.0             9.0          10.0
# 4       7.0             7.0           8.0
# 5       8.0             8.0           6.0
# 6      10.0            10.0          10.0
# 7       7.0             7.0           7.0
# 8       8.0             9.0           8.0
# 9       NaN             NaN           NaN
#
#                                     long_answer_main  \
# 0  Yes the bot fact checked, but it didn’t feel l...
# 1                                                NaN
# 2                                                NaN
# 3  Saying "False in three distinct ways simultane...
# 4  The bot had a good amount of contextualizing i...
# 5                                                NaN
# 6                                                NaN
# 7  The bot was very informative, adding context t...
# 8                                                NaN
# 9                                                NaN
#
#    reply_interest_following reply_interest_engaging  \
# 0                       6.0                     6.0
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       6.0                     6.0
# 5                       5.0                     5.0
# 6                       NaN                     NaN
# 7                       5.0                     5.0
# 8                       5.0                     5.0
# 9                       NaN                     NaN
#
#                                    long_answer_extra
# 0  Due to the lack of depth of the reply, it didn...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The finality in the post, plus the contents it...
# 5                                                NaN
# 6                                                NaN
# 7  The response didn’t illicit any particular wan...
# 8                                                NaN
# 9                                                NaN
#
# [10 rows x 102 columns]

# %%
for i in range(2, len(daily_survey_df.columns.values)):
    daily_survey_df.columns.values[i] = f"{daily_survey_df.columns.values[i]}{int((i - 1) / 10)}"

# %%
daily_survey_df.head(10)
# Out:
#             Timestamp                       email valid_reply0 reply_id0  \
# 0   5/27/2026 2:13:55      jerrybro2001@gmail.com          Yes      MNFX
# 1   5/27/2026 2:26:47              cluong9@uw.edu          Yes      PLHS
# 2  5/27/2026 11:33:32  dlee1004@cs.washington.edu          Yes      BJRH
# 3   5/28/2026 1:00:29              cluong9@uw.edu          Yes      LGYK
# 4   5/28/2026 1:13:24      jerrybro2001@gmail.com          Yes      CGVS
# 5  5/28/2026 14:23:27             alim1127@uw.edu          Yes      RNHQ
# 6  5/28/2026 23:47:13              cluong9@uw.edu          Yes      GBAE
# 7   5/29/2026 0:43:45      jerrybro2001@gmail.com           No      CACD
# 8  5/29/2026 14:05:52             alim1127@uw.edu          Yes      ZYFG
# 9  5/29/2026 15:19:25                hsu01@uw.edu          Yes      VQCQ
#
#      parent_author0  enjoyment0  informativeness0  satisfaction0  \
# 0    ForgiatoBlow47         6.0               5.0            5.0
# 1    @MaeveHalligan         8.0              10.0            6.0
# 2   @KristanHawkins         7.0               8.0            6.0
# 3  @realBrandonGill        10.0               9.0            9.0
# 4     TruthFairy131         8.0               8.0            8.0
# 5  @TripleNetInvest         6.0               8.0            7.0
# 6    @laurenboebert         8.0               9.0            9.0
# 7        Notwokenow         NaN               NaN            NaN
# 8        @benonwine         7.0               8.0            7.0
# 9       @kangminlee         8.0               7.0            5.0
#
#                                    long_answer_main0  \
# 0  The bot didn’t really provide many details tha...
# 1  Though brief in its reply, the bot did fact ch...
# 2                                                NaN
# 3  Phenomenal work on the bot, I really liked how...
# 4  The bot gave a lot of details that were suppor...
# 5                                                NaN
# 6  Nothing about the bots reply, but I'm really l...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    reply_interest_following0  ...  valid_reply9 reply_id9  parent_author9  \
# 0                        6.0  ...           Yes      ETKQ   SenTuberville
# 1                        NaN  ...            No       NaN             NaN
# 2                        NaN  ...            No       NaN             NaN
# 3                        NaN  ...           Yes      PHKL     @joeroganhq
# 4                        5.0  ...           Yes      QGBU         Milajoy
# 5                        3.0  ...            No      NYLK      @lapdoteth
# 6                        NaN  ...           Yes      PHGK     @_Achetypal
# 7                        NaN  ...           Yes      AGNQ      WhiteHouse
# 8                        5.0  ...           Yes      QXAT  @ChuckGrassley
# 9                        5.0  ...            No       NaN             NaN
#
#   enjoyment9 informativeness9  satisfaction9  \
# 0        7.0              7.0            6.0
# 1        NaN              NaN            NaN
# 2        NaN              NaN            NaN
# 3       10.0              9.0           10.0
# 4        7.0              7.0            8.0
# 5        8.0              8.0            6.0
# 6       10.0             10.0           10.0
# 7        7.0              7.0            7.0
# 8        8.0              9.0            8.0
# 9        NaN              NaN            NaN
#
#                                    long_answer_main9  \
# 0  Yes the bot fact checked, but it didn’t feel l...
# 1                                                NaN
# 2                                                NaN
# 3  Saying "False in three distinct ways simultane...
# 4  The bot had a good amount of contextualizing i...
# 5                                                NaN
# 6                                                NaN
# 7  The bot was very informative, adding context t...
# 8                                                NaN
# 9                                                NaN
#
#    reply_interest_following9 reply_interest_engaging9  \
# 0                        6.0                      6.0
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        6.0                      6.0
# 5                        5.0                      5.0
# 6                        NaN                      NaN
# 7                        5.0                      5.0
# 8                        5.0                      5.0
# 9                        NaN                      NaN
#
#                                  long_answer_extra10
# 0  Due to the lack of depth of the reply, it didn...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The finality in the post, plus the contents it...
# 5                                                NaN
# 6                                                NaN
# 7  The response didn’t illicit any particular wan...
# 8                                                NaN
# 9                                                NaN
#
# [10 rows x 102 columns]

# %%
daily_survey_df_long = pd.wide_to_long(
    daily_survey_df,
    stubnames=[
        'valid_reply',
        'reply_id',
        'parent_author',
        'enjoyment',
        'informativeness',
        'satisfaction',
        'long_answer_main',
        'reply_interest_following',
        'reply_interest_engaging',
        'long_answer_extra',
    ],
    i='Timestamp',
    j='temp',
).reset_index()[[
    'Timestamp',
    'email',
    'valid_reply',
    'reply_id',
    'parent_author',
    'enjoyment',
    'informativeness',
    'satisfaction',
    'long_answer_main',
    'reply_interest_following',
    'reply_interest_engaging',
    'long_answer_extra',
]]

# %%
daily_survey_df_long.head(10)
# Out:
#             Timestamp                       email valid_reply reply_id  \
# 0   5/27/2026 2:13:55      jerrybro2001@gmail.com         Yes     MNFX
# 1   5/27/2026 2:26:47              cluong9@uw.edu         Yes     PLHS
# 2  5/27/2026 11:33:32  dlee1004@cs.washington.edu         Yes     BJRH
# 3   5/28/2026 1:00:29              cluong9@uw.edu         Yes     LGYK
# 4   5/28/2026 1:13:24      jerrybro2001@gmail.com         Yes     CGVS
# 5  5/28/2026 14:23:27             alim1127@uw.edu         Yes     RNHQ
# 6  5/28/2026 23:47:13              cluong9@uw.edu         Yes     GBAE
# 7   5/29/2026 0:43:45      jerrybro2001@gmail.com          No     CACD
# 8  5/29/2026 14:05:52             alim1127@uw.edu         Yes     ZYFG
# 9  5/29/2026 15:19:25                hsu01@uw.edu         Yes     VQCQ
#
#       parent_author  enjoyment  informativeness  satisfaction  \
# 0    ForgiatoBlow47        6.0              5.0           5.0
# 1    @MaeveHalligan        8.0             10.0           6.0
# 2   @KristanHawkins        7.0              8.0           6.0
# 3  @realBrandonGill       10.0              9.0           9.0
# 4     TruthFairy131        8.0              8.0           8.0
# 5  @TripleNetInvest        6.0              8.0           7.0
# 6    @laurenboebert        8.0              9.0           9.0
# 7        Notwokenow        NaN              NaN           NaN
# 8        @benonwine        7.0              8.0           7.0
# 9       @kangminlee        8.0              7.0           5.0
#
#                                     long_answer_main  \
# 0  The bot didn’t really provide many details tha...
# 1  Though brief in its reply, the bot did fact ch...
# 2                                                NaN
# 3  Phenomenal work on the bot, I really liked how...
# 4  The bot gave a lot of details that were suppor...
# 5                                                NaN
# 6  Nothing about the bots reply, but I'm really l...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    reply_interest_following  reply_interest_engaging long_answer_extra
# 0                       6.0                      6.0               NaN
# 1                       NaN                      NaN               NaN
# 2                       NaN                      NaN               NaN
# 3                       NaN                      NaN               NaN
# 4                       5.0                      5.0               NaN
# 5                       3.0                      5.0               NaN
# 6                       NaN                      NaN               NaN
# 7                       NaN                      NaN               NaN
# 8                       5.0                      5.0               NaN
# 9                       5.0                      5.0               NaN

# %%
daily_survey_df_full = pd.merge(
    daily_survey_df_long,
    pre_survey_df,
    on='email',
    how='left'
)

# %%
daily_survey_df_full.head(10)
# Out:
#             Timestamp                       email valid_reply reply_id  \
# 0   5/27/2026 2:13:55      jerrybro2001@gmail.com         Yes     MNFX
# 1   5/27/2026 2:26:47              cluong9@uw.edu         Yes     PLHS
# 2  5/27/2026 11:33:32  dlee1004@cs.washington.edu         Yes     BJRH
# 3   5/28/2026 1:00:29              cluong9@uw.edu         Yes     LGYK
# 4   5/28/2026 1:13:24      jerrybro2001@gmail.com         Yes     CGVS
# 5  5/28/2026 14:23:27             alim1127@uw.edu         Yes     RNHQ
# 6  5/28/2026 23:47:13              cluong9@uw.edu         Yes     GBAE
# 7   5/29/2026 0:43:45      jerrybro2001@gmail.com          No     CACD
# 8  5/29/2026 14:05:52             alim1127@uw.edu         Yes     ZYFG
# 9  5/29/2026 15:19:25                hsu01@uw.edu         Yes     VQCQ
#
#       parent_author  enjoyment  informativeness  satisfaction  \
# 0    ForgiatoBlow47        6.0              5.0           5.0
# 1    @MaeveHalligan        8.0             10.0           6.0
# 2   @KristanHawkins        7.0              8.0           6.0
# 3  @realBrandonGill       10.0              9.0           9.0
# 4     TruthFairy131        8.0              8.0           8.0
# 5  @TripleNetInvest        6.0              8.0           7.0
# 6    @laurenboebert        8.0              9.0           9.0
# 7        Notwokenow        NaN              NaN           NaN
# 8        @benonwine        7.0              8.0           7.0
# 9       @kangminlee        8.0              7.0           5.0
#
#                                     long_answer_main  \
# 0  The bot didn’t really provide many details tha...
# 1  Though brief in its reply, the bot did fact ch...
# 2                                                NaN
# 3  Phenomenal work on the bot, I really liked how...
# 4  The bot gave a lot of details that were suppor...
# 5                                                NaN
# 6  Nothing about the bots reply, but I'm really l...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    reply_interest_following  reply_interest_engaging long_answer_extra  \
# 0                       6.0                      6.0               NaN
# 1                       NaN                      NaN               NaN
# 2                       NaN                      NaN               NaN
# 3                       NaN                      NaN               NaN
# 4                       5.0                      5.0               NaN
# 5                       3.0                      5.0               NaN
# 6                       NaN                      NaN               NaN
# 7                       NaN                      NaN               NaN
# 8                       5.0                      5.0               NaN
# 9                       5.0                      5.0               NaN
#
#           username tone_condition topic_condition presurvey_timestamp  \
# 0       NekoHuffer        neutral     Immigration     5/24/2026 12:06
# 1     Cheezwhizcat      satirical     LGBT Issues     5/22/2026 21:59
# 2   GarlicBread889      agreeable      Healthcare     5/25/2026 16:31
# 3     Cheezwhizcat      satirical     LGBT Issues     5/22/2026 21:59
# 4       NekoHuffer        neutral     Immigration     5/24/2026 12:06
# 5        lommyt7s8        neutral  Cost of Living     5/25/2026 17:39
# 6     Cheezwhizcat      satirical     LGBT Issues     5/22/2026 21:59
# 7       NekoHuffer        neutral     Immigration     5/24/2026 12:06
# 8        lommyt7s8        neutral  Cost of Living     5/25/2026 17:39
# 9  VanillaMatchaHK      agreeable            Race     5/26/2026 15:44
#
#   registration_date  notes
# 0         5/24/2026    NaN
# 1         5/24/2026    NaN
# 2         5/26/2026    NaN
# 3         5/24/2026    NaN
# 4         5/24/2026    NaN
# 5         5/26/2026    NaN
# 6         5/24/2026    NaN
# 7         5/24/2026    NaN
# 8         5/26/2026    NaN
# 9         5/27/2026    NaN

# %%
daily_survey_df_final = daily_survey_df_full[(daily_survey_df_full['valid_reply'] == 'Yes')]
daily_survey_df_final = daily_survey_df_final.dropna(subset=[
    'email',
    'enjoyment',
    'informativeness',
    'satisfaction'
])

# %%
len(daily_survey_df_final)
# Out:
# 312

# %%
daily_survey_df_final.head(10)
# Out:
#              Timestamp                       email valid_reply reply_id  \
# 0    5/27/2026 2:13:55      jerrybro2001@gmail.com         Yes     MNFX
# 1    5/27/2026 2:26:47              cluong9@uw.edu         Yes     PLHS
# 2   5/27/2026 11:33:32  dlee1004@cs.washington.edu         Yes     BJRH
# 3    5/28/2026 1:00:29              cluong9@uw.edu         Yes     LGYK
# 4    5/28/2026 1:13:24      jerrybro2001@gmail.com         Yes     CGVS
# 5   5/28/2026 14:23:27             alim1127@uw.edu         Yes     RNHQ
# 6   5/28/2026 23:47:13              cluong9@uw.edu         Yes     GBAE
# 8   5/29/2026 14:05:52             alim1127@uw.edu         Yes     ZYFG
# 9   5/29/2026 15:19:25                hsu01@uw.edu         Yes     VQCQ
# 10  5/30/2026 13:20:39  dlee1004@cs.washington.edu         Yes     GWAF
#
#        parent_author  enjoyment  informativeness  satisfaction  \
# 0     ForgiatoBlow47        6.0              5.0           5.0
# 1     @MaeveHalligan        8.0             10.0           6.0
# 2    @KristanHawkins        7.0              8.0           6.0
# 3   @realBrandonGill       10.0              9.0           9.0
# 4      TruthFairy131        8.0              8.0           8.0
# 5   @TripleNetInvest        6.0              8.0           7.0
# 6     @laurenboebert        8.0              9.0           9.0
# 8         @benonwine        7.0              8.0           7.0
# 9        @kangminlee        8.0              7.0           5.0
# 10  @AmericaPapaBear        8.0              9.0           7.0
#
#                                      long_answer_main  \
# 0   The bot didn’t really provide many details tha...
# 1   Though brief in its reply, the bot did fact ch...
# 2                                                 NaN
# 3   Phenomenal work on the bot, I really liked how...
# 4   The bot gave a lot of details that were suppor...
# 5                                                 NaN
# 6   Nothing about the bots reply, but I'm really l...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#     reply_interest_following  reply_interest_engaging long_answer_extra  \
# 0                        6.0                      6.0               NaN
# 1                        NaN                      NaN               NaN
# 2                        NaN                      NaN               NaN
# 3                        NaN                      NaN               NaN
# 4                        5.0                      5.0               NaN
# 5                        3.0                      5.0               NaN
# 6                        NaN                      NaN               NaN
# 8                        5.0                      5.0               NaN
# 9                        5.0                      5.0               NaN
# 10                       NaN                      NaN               NaN
#
#            username tone_condition topic_condition presurvey_timestamp  \
# 0        NekoHuffer        neutral     Immigration     5/24/2026 12:06
# 1      Cheezwhizcat      satirical     LGBT Issues     5/22/2026 21:59
# 2    GarlicBread889      agreeable      Healthcare     5/25/2026 16:31
# 3      Cheezwhizcat      satirical     LGBT Issues     5/22/2026 21:59
# 4        NekoHuffer        neutral     Immigration     5/24/2026 12:06
# 5         lommyt7s8        neutral  Cost of Living     5/25/2026 17:39
# 6      Cheezwhizcat      satirical     LGBT Issues     5/22/2026 21:59
# 8         lommyt7s8        neutral  Cost of Living     5/25/2026 17:39
# 9   VanillaMatchaHK      agreeable            Race     5/26/2026 15:44
# 10   GarlicBread889      agreeable      Healthcare     5/25/2026 16:31
#
#    registration_date  notes
# 0          5/24/2026    NaN
# 1          5/24/2026    NaN
# 2          5/26/2026    NaN
# 3          5/24/2026    NaN
# 4          5/24/2026    NaN
# 5          5/26/2026    NaN
# 6          5/24/2026    NaN
# 8          5/26/2026    NaN
# 9          5/27/2026    NaN
# 10         5/26/2026    NaN

# %%
import matplotlib.pyplot as plt

plt.style.use('default')
style = {
    'boxprops': {'color': 'tab:blue'},
    'whiskerprops': {'color': 'tab:blue'},
    'medianprops': {'color': 'tab:green'}
}
enjoyment_boxplot = daily_survey_df_full.boxplot(column='enjoyment', by='tone_condition', **style)
plt.savefig("enjoyment_boxplot.png", bbox_inches='tight', dpi=300)

# %%
informativeness_boxplot = daily_survey_df_full.boxplot(column='informativeness', by='tone_condition', **style)
plt.savefig("informativeness_boxplot.png", bbox_inches='tight', dpi=300)

# %%
satisfaction_boxplot = daily_survey_df_full.boxplot(column='satisfaction', by='tone_condition', **style)
plt.savefig("satisfaction_boxplot.png", bbox_inches='tight', dpi=300)

# %%
import statsmodels.formula.api as smf

# Reference Group: Neutral
# Dependent Variable: Enjoyment
model_intercept = smf.mixedlm("enjoyment ~ C(tone_condition, Treatment(reference='neutral'))", daily_survey_df_final, groups=daily_survey_df_final['email'])
result_intercept = model_intercept.fit()

print()
print("Dependent Variable: Enjoyment")
print(result_intercept.pvalues["C(tone_condition, Treatment(reference='neutral'))[T.agreeable]"])
# Out:
# Dependent Variable: Enjoyment
# 0.4430725072001096

# %%
import statsmodels.formula.api as smf

pvals = {}
def record_pvals(results, reference_group, dependent_var):
    if dependent_var not in pvals:
        pvals[dependent_var] = {}
    for treatment_group in ['agreeable', 'neutral', 'satirical']:
        if treatment_group != reference_group:
            # Generate standard ordering for each group pair to avoid adding duplicates
            comparison_groups = [reference_group, treatment_group]
            comparison_groups.sort()
            pval_key = f'{comparison_groups[0]}-{comparison_groups[1]}'

            # Add pval to dict
            if pval_key not in pvals[dependent_var]:
                results_key = f"C(tone_condition, Treatment(reference='{reference_group}'))[T.{treatment_group}]"
                pvals[dependent_var][pval_key] = results.pvalues[results_key]

def model(reference_group, dependent_var, data=None):
    if data is None:
        data = daily_survey_df_final

    model_intercept = smf.mixedlm(
        f"{dependent_var} ~ C(tone_condition, Treatment(reference='{reference_group}'))",
        data,
        groups=data['email']
    )
    result_intercept = model_intercept.fit()

    print()
    print(f"Reference Group: {reference_group} | Dependent Variable: {dependent_var}")
    print(result_intercept.summary())

    record_pvals(result_intercept, reference_group, dependent_var)
    return result_intercept

def model_all():
    for reference_group in ['agreeable', 'neutral', 'satirical']:
        for dependent_var in ['enjoyment', 'informativeness', 'satisfaction']:
            model(reference_group=reference_group, dependent_var=dependent_var)

# %%
model_all()
# Out:
# Reference Group: agreeable | Dependent Variable: enjoyment
#                                   Mixed Linear Model Regression Results
# ==========================================================================================================
# Model:                             MixedLM                  Dependent Variable:                  enjoyment
# No. Observations:                  312                      Method:                              REML
# No. Groups:                        10                       Scale:                               1.6888
# Min. group size:                   6                        Log-Likelihood:                      -536.0685
# Max. group size:                   47                       Converged:                           Yes
# Mean group size:                   31.2
# ----------------------------------------------------------------------------------------------------------
#                                                                  Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                                        6.787    0.511 13.280 0.000  5.785  7.789
# C(tone_condition, Treatment(reference='agreeable'))[T.neutral]   0.593    0.773  0.767 0.443 -0.922  2.108
# C(tone_condition, Treatment(reference='agreeable'))[T.satirical] 1.062    0.769  1.381 0.167 -0.445  2.568
# Group Var                                                        0.944    0.428
# ==========================================================================================================
#
#
# Reference Group: agreeable | Dependent Variable: informativeness
#                                   Mixed Linear Model Regression Results
# ==========================================================================================================
# Model:                           MixedLM                Dependent Variable:                informativeness
# No. Observations:                312                    Method:                            REML
# No. Groups:                      10                     Scale:                             1.8396
# Min. group size:                 6                      Log-Likelihood:                    -548.1132
# Max. group size:                 47                     Converged:                         Yes
# Mean group size:                 31.2
# ----------------------------------------------------------------------------------------------------------
#                                                                  Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                                        7.190    0.453 15.871 0.000  6.303  8.078
# C(tone_condition, Treatment(reference='agreeable'))[T.neutral]   0.435    0.683  0.636 0.525 -0.904  1.774
# C(tone_condition, Treatment(reference='agreeable'))[T.satirical] 0.955    0.678  1.409 0.159 -0.374  2.283
# Group Var                                                        0.714    0.321
# ==========================================================================================================
#
#
# Reference Group: agreeable | Dependent Variable: satisfaction
#                                   Mixed Linear Model Regression Results
# ==========================================================================================================
# Model:                            MixedLM                 Dependent Variable:                 satisfaction
# No. Observations:                 312                     Method:                             REML
# No. Groups:                       10                      Scale:                              2.2300
# Min. group size:                  6                       Log-Likelihood:                     -576.9792
# Max. group size:                  47                      Converged:                          Yes
# Mean group size:                  31.2
# ----------------------------------------------------------------------------------------------------------
#                                                                  Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                                        6.888    0.442 15.575 0.000  6.022  7.755
# C(tone_condition, Treatment(reference='agreeable'))[T.neutral]   0.607    0.665  0.913 0.361 -0.697  1.911
# C(tone_condition, Treatment(reference='agreeable'))[T.satirical] 1.124    0.658  1.707 0.088 -0.166  2.415
# Group Var                                                        0.655    0.276
# ==========================================================================================================
#
#
# Reference Group: neutral | Dependent Variable: enjoyment
#                                   Mixed Linear Model Regression Results
# =========================================================================================================
# Model:                              MixedLM                 Dependent Variable:                 enjoyment
# No. Observations:                   312                     Method:                             REML
# No. Groups:                         10                      Scale:                              1.6888
# Min. group size:                    6                       Log-Likelihood:                     -536.0685
# Max. group size:                    47                      Converged:                          Yes
# Mean group size:                    31.2
# ---------------------------------------------------------------------------------------------------------
#                                                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                                       7.380    0.580 12.727 0.000  6.243  8.516
# C(tone_condition, Treatment(reference='neutral'))[T.agreeable] -0.593    0.773 -0.767 0.443 -2.108  0.922
# C(tone_condition, Treatment(reference='neutral'))[T.satirical]  0.469    0.816  0.574 0.566 -1.131  2.068
# Group Var                                                       0.944    0.428
# =========================================================================================================
#
#
# Reference Group: neutral | Dependent Variable: informativeness
#                                   Mixed Linear Model Regression Results
# =========================================================================================================
# Model:                            MixedLM               Dependent Variable:               informativeness
# No. Observations:                 312                   Method:                           REML
# No. Groups:                       10                    Scale:                            1.8396
# Min. group size:                  6                     Log-Likelihood:                   -548.1132
# Max. group size:                  47                    Converged:                        Yes
# Mean group size:                  31.2
# ---------------------------------------------------------------------------------------------------------
#                                                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                                       7.625    0.511 14.913 0.000  6.623  8.627
# C(tone_condition, Treatment(reference='neutral'))[T.agreeable] -0.435    0.683 -0.636 0.525 -1.774  0.904
# C(tone_condition, Treatment(reference='neutral'))[T.satirical]  0.520    0.718  0.724 0.469 -0.888  1.928
# Group Var                                                       0.714    0.321
# =========================================================================================================
#
#
# Reference Group: neutral | Dependent Variable: satisfaction
#                                   Mixed Linear Model Regression Results
# =========================================================================================================
# Model:                             MixedLM                Dependent Variable:                satisfaction
# No. Observations:                  312                    Method:                            REML
# No. Groups:                        10                     Scale:                             2.2300
# Min. group size:                   6                      Log-Likelihood:                    -576.9792
# Max. group size:                   47                     Converged:                         Yes
# Mean group size:                   31.2
# ---------------------------------------------------------------------------------------------------------
#                                                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                                       7.496    0.497 15.092 0.000  6.522  8.469
# C(tone_condition, Treatment(reference='neutral'))[T.agreeable] -0.607    0.665 -0.913 0.361 -1.911  0.697
# C(tone_condition, Treatment(reference='neutral'))[T.satirical]  0.517    0.697  0.742 0.458 -0.848  1.882
# Group Var                                                       0.655    0.276
# =========================================================================================================
#
#
# Reference Group: satirical | Dependent Variable: enjoyment
#                                    Mixed Linear Model Regression Results
# ===========================================================================================================
# Model:                              MixedLM                  Dependent Variable:                  enjoyment
# No. Observations:                   312                      Method:                              REML
# No. Groups:                         10                       Scale:                               1.6888
# Min. group size:                    6                        Log-Likelihood:                      -536.0685
# Max. group size:                    47                       Converged:                           Yes
# Mean group size:                    31.2
# -----------------------------------------------------------------------------------------------------------
#                                                                  Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                                         7.848    0.574 13.664 0.000  6.723  8.974
# C(tone_condition, Treatment(reference='satirical'))[T.agreeable] -1.062    0.769 -1.381 0.167 -2.568  0.445
# C(tone_condition, Treatment(reference='satirical'))[T.neutral]   -0.469    0.816 -0.574 0.566 -2.068  1.131
# Group Var                                                         0.944    0.428
# ===========================================================================================================
#
#
# Reference Group: satirical | Dependent Variable: informativeness
#                                    Mixed Linear Model Regression Results
# ===========================================================================================================
# Model:                            MixedLM                Dependent Variable:                informativeness
# No. Observations:                 312                    Method:                            REML
# No. Groups:                       10                     Scale:                             1.8396
# Min. group size:                  6                      Log-Likelihood:                    -548.1132
# Max. group size:                  47                     Converged:                         Yes
# Mean group size:                  31.2
# -----------------------------------------------------------------------------------------------------------
#                                                                  Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                                         8.145    0.505 16.142 0.000  7.156  9.134
# C(tone_condition, Treatment(reference='satirical'))[T.agreeable] -0.955    0.678 -1.409 0.159 -2.283  0.374
# C(tone_condition, Treatment(reference='satirical'))[T.neutral]   -0.520    0.718 -0.724 0.469 -1.928  0.888
# Group Var                                                         0.714    0.321
# ===========================================================================================================
#
#
# Reference Group: satirical | Dependent Variable: satisfaction
#                                    Mixed Linear Model Regression Results
# ===========================================================================================================
# Model:                             MixedLM                 Dependent Variable:                 satisfaction
# No. Observations:                  312                     Method:                             REML
# No. Groups:                        10                      Scale:                              2.2300
# Min. group size:                   6                       Log-Likelihood:                     -576.9792
# Max. group size:                   47                      Converged:                          Yes
# Mean group size:                   31.2
# -----------------------------------------------------------------------------------------------------------
#                                                                  Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                                         8.013    0.488 16.409 0.000  7.056  8.970
# C(tone_condition, Treatment(reference='satirical'))[T.agreeable] -1.124    0.658 -1.707 0.088 -2.415  0.166
# C(tone_condition, Treatment(reference='satirical'))[T.neutral]   -0.517    0.697 -0.742 0.458 -1.882  0.848
# Group Var                                                         0.655    0.276
# ===========================================================================================================

# %%
print(pvals)
# Out:
# {'enjoyment': {'agreeable-neutral': np.float64(0.4430725072001014), 'agreeable-satirical': np.float64(0.1672878570694396), 'neutral-satirical': np.float64(0.565814208850555)}, 'informativeness': {'agreeable-neutral': np.float64(0.5245652288873771), 'agreeable-satirical': np.float64(0.15896954633159166), 'neutral-satirical': np.float64(0.4690432191407693)}, 'satisfaction': {'agreeable-neutral': np.float64(0.36139034370296463), 'agreeable-satirical': np.float64(0.08776320266442932), 'neutral-satirical': np.float64(0.45792329743615234)}}

# %%
import json
import statsmodels.stats.multitest as multitest

raw_pvals = []
for comparison in ['agreeable-satirical', 'neutral-satirical', 'agreeable-satirical']:
    for dependent_var in ['enjoyment', 'informativeness', 'satisfaction']:
        raw_pvals.append(pvals[dependent_var][comparison])

_, raw_pvals_corrected, _, _ = multitest.multipletests(raw_pvals, alpha=0.05, method='holm')
pvals_corrected = {}
i = 0
for comparison in ['agreeable-satirical', 'neutral-satirical', 'agreeable-satirical']:
    for dependent_var in ['enjoyment', 'informativeness', 'satisfaction']:
        if dependent_var not in pvals_corrected:
            pvals_corrected[dependent_var] = {}
        pvals_corrected[dependent_var][comparison] = raw_pvals[i]
        i += 1

print(json.dumps(pvals_corrected, indent=4))
# Out:
# {
#     "enjoyment": {
#         "agreeable-satirical": 0.1672878570694396,
#         "neutral-satirical": 0.565814208850555
#     },
#     "informativeness": {
#         "agreeable-satirical": 0.15896954633159166,
#         "neutral-satirical": 0.4690432191407693
#     },
#     "satisfaction": {
#         "agreeable-satirical": 0.08776320266442932,
#         "neutral-satirical": 0.45792329743615234
#     }
# }
